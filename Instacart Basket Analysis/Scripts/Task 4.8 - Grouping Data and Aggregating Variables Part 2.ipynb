# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/andrew/Documents/Data Analyst Course/Data Immersion/Achievement 4/Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column
# grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
df = ords_prods_merge

# %%
df.shape
# Out:
# (32435059, 20)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
# 5   2398795        1             2                   3           7
# 6   2398795        1             2                   3           7
# 7   2398795        1             2                   3           7
# 8   2398795        1             2                   3           7
# 9   2398795        1             2                   3           7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     15.457838
# 2.0     17.277920
# 3.0     17.170395
# 4.0     17.811403
# 5.0     15.215751
# 6.0     16.439806
# 7.0     17.225802
# 8.0     15.340650
# 9.0     15.895474
# 10.0    20.197148
# 11.0    16.170638
# 12.0    15.887671
# 13.0    16.583536
# 14.0    16.773669
# 15.0    16.165037
# 16.0    17.665606
# 17.0    15.694469
# 18.0    19.310397
# 19.0    17.177343
# 20.0    16.473447
# 21.0    22.902379
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              15.457838   1  99
# 2.0              17.277920   1  99
# 3.0              17.170395   1  99
# 4.0              17.811403   1  99
# 5.0              15.215751   1  99
# 6.0              16.439806   1  99
# 7.0              17.225802   1  99
# 8.0              15.340650   1  99
# 9.0              15.895474   1  99
# 10.0             20.197148   1  99
# 11.0             16.170638   1  99
# 12.0             15.887671   1  99
# 13.0             16.583536   1  99
# 14.0             16.773669   1  99
# 15.0             16.165037   1  99
# 16.0             17.665606   1  99
# 17.0             15.694469   1  99
# 18.0             19.310397   1  99
# 19.0             17.177343   1  99
# 20.0             16.473447   1  99
# 21.0             22.902379   1  99

# %%
# 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers
# using the transform() and loc() functions.

# %%
df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2539329        1             1                   2           8
# 1    2539329        1             1                   2           8
# 2    2539329        1             1                   2           8
# 3    2539329        1             1                   2           8
# 4    2539329        1             1                   2           8
# 5    2398795        1             2                   3           7
# 6    2398795        1             2                   3           7
# 7    2398795        1             2                   3           7
# 8    2398795        1             2                   3           7
# 9    2398795        1             2                   3           7
# 10   2398795        1             2                   3           7
# 11    473747        1             3                   3          12
# 12    473747        1             3                   3          12
# ...

# %%
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: loyalty_flag, dtype: int64

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...  department_id  prices  \
# 0                                     Soda  ...            7.0     9.0
# ...

# %%
# 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the
# three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the
# product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re
# trying to determine is whether the prices of products purchased by loyal customers differ from those purchased
# by regular or new customers.

# %%
df.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.773575  1.0  25.0
# New customer      7.801206  1.0  25.0
# Regular customer  7.798262  1.0  25.0

# %%
# removing max price as 99999 is too high!

# %%
ords_prods_merge = ords_prods_merge[ords_prods_merge.prices <200.0]

# %%
df.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.773575  1.0  25.0
# New customer      7.801206  1.0  25.0
# Regular customer  7.798262  1.0  25.0

# %%
# Loyal customers spend on average 5 cents less than new customers.
# Regular customers spend just over 4 cents more than loyal customers

# %%
# 6. The team now wants to target different types of spenders in their marketing campaigns. This can be
# achieved by looking at the prices of the items people are buying. Create a spending flag for each user
# based on the average price across all their orders using the following criteria:

# %%
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”

# %%
df.groupby('user_id').agg({'prices': ['mean']})
# Out:
#            prices
#              mean
# user_id
# 1        6.367797
# 2        7.515897
# 3        8.197727
# 4        8.205556
# 5        9.189189
# ...           ...
# 206205   8.909375
# 206206   7.646667
# 206207   7.313453
# 206208   8.366617
# 206209   7.058915
#
# [206209 rows x 1 columns]

# %%
df['user_avg_price'] = df.groupby(['user_id'])['prices'].transform(np.max)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...  department_id  prices  \
# 0                                     Soda  ...            7.0     9.0
# ...

# %%
df['user_avg_price'] = df.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...  department_id  prices  \
# 0                                     Soda  ...            7.0     9.0
# ...

# %%
df.sort_values(by='user_id', ascending=True).head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2539329        1             1                   2           8
# 32   3367565        1             6                   2           7
# 33    550135        1             7                   1           9
# 34    550135        1             7                   1           9
# 35    550135        1             7                   1           9
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 32                    19.0       25133                  4          1
# 33                    20.0         196                  1          1
# 34                    20.0       10258                  2          1
# 35                    20.0       12427                  3          1
#
#              product_name  ...  department_id  prices  _merge  \
# 0                    Soda  ...            7.0     9.0    both
# ...

# %%
df['user_avg_price'].describe()
# Out:
# count    3.243506e+07
# mean     7.790949e+00
# std      7.348682e-01
# min      1.000000e+00
# 25%      7.378442e+00
# 50%      7.811905e+00
# 75%      8.229328e+00
# max      2.320000e+01
# Name: user_avg_price, dtype: float64

# %%
df.loc[df['user_avg_price'] < 10, 'spending_habit'] = 'Lower spender'
df.loc[df['user_avg_price'] >= 10, 'spending_habit'] = 'Higher spender'

# %%
df[['user_id', 'user_avg_price', 'spending_habit']].head()
# Out:
#    user_id  user_avg_price spending_habit
# 0        1        6.367797  Lower spender
# 1        1        6.367797  Lower spender
# 2        1        6.367797  Lower spender
# 3        1        6.367797  Lower spender
# 4        1        6.367797  Lower spender

# %%
df.loc[df['spending_habit'] == 'Higher spender']
# Out:
#           order_id  user_id  order_number  orders_day_of_week  order_time  \
# 9435       2451656       72             1                   5          15
# 9436       2451656       72             1                   5          15
# 9437       2451656       72             1                   5          15
# 9438       2451656       72             1                   5          15
# 9439       2451656       72             1                   5          15
# ...            ...      ...           ...                 ...         ...
# 32423131   2145768   206121             2                   6          10
# 32423132   3333842   206121             3                   4          13
# 32423133   3333842   206121             3                   4          13
# 32423134   3333842   206121             3                   4          13
# 32423135   3333842   206121             3                   4          13
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
# 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to
# buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. 
# Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median
# in the “days_since_prior_order” column. The criteria for the flag should be as follows:

# %%
# A. If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a 
# “Non-frequent customer.”

# %%
df['median_order_duration'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df[['user_id', 'user_avg_price', 'spending_habit','median_order_duration']].head()
# Out:
#    user_id  user_avg_price spending_habit  median_order_duration
# 0        1        6.367797  Lower spender                   20.5
# 1        1        6.367797  Lower spender                   20.5
# 2        1        6.367797  Lower spender                   20.5
# 3        1        6.367797  Lower spender                   20.5
# 4        1        6.367797  Lower spender                   20.5

# %%
df.loc[df['median_order_duration'] > 20, 'order_frequency'] = 'Non-frequent customer'
df.loc[(df['median_order_duration'] > 10) & (df['median_order_duration'] <= 20), 'order_frequency'] = 'Regular customer'
df.loc[df['median_order_duration'] < 10, 'order_frequency'] = 'Frequent customer'

# %%
df[['user_id', 'user_avg_price', 'spending_habit','order_frequency','median_order_duration']].head()
# Out:
#    user_id  user_avg_price spending_habit        order_frequency  \
# 0        1        6.367797  Lower spender  Non-frequent customer
# 1        1        6.367797  Lower spender  Non-frequent customer
# 2        1        6.367797  Lower spender  Non-frequent customer
# 3        1        6.367797  Lower spender  Non-frequent customer
# 4        1        6.367797  Lower spender  Non-frequent customer
#
#    median_order_duration
# 0                   20.5
# 1                   20.5
# 2                   20.5
# 3                   20.5
# 4                   20.5

# %%
df[['user_id', 'user_avg_price', 'spending_habit','order_frequency','median_order_duration']].head(100)
# Out:
#     user_id  user_avg_price spending_habit        order_frequency  \
# 0         1        6.367797  Lower spender  Non-frequent customer
# 1         1        6.367797  Lower spender  Non-frequent customer
# 2         1        6.367797  Lower spender  Non-frequent customer
# 3         1        6.367797  Lower spender  Non-frequent customer
# 4         1        6.367797  Lower spender  Non-frequent customer
# ..      ...             ...            ...                    ...
# 95        2        7.515897  Lower spender       Regular customer
# 96        2        7.515897  Lower spender       Regular customer
# 97        2        7.515897  Lower spender       Regular customer
# 98        2        7.515897  Lower spender       Regular customer
# 99        2        7.515897  Lower spender       Regular customer
#
#     median_order_duration
# 0                    20.5
# 1                    20.5
# 2                    20.5
# 3                    20.5
# 4                    20.5
# ...

# %%
df.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))
