# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/andrew/Documents/Data Analyst Course/Data Immersion/Achievement 4/Instacart Basket Analysis'

# %%
# In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
df_ords_prods_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
df_ords_prods_combined.shape
# Out:
# (32434489, 10)

# %%
df_prods = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'Products_cleaned.pkl'))

# %%
df_prods.shape
# Out:
# (49672, 5)

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_prods_combined_1 = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
df_ords_prods_combined_1
# Out:
#           order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0          2539329        1             1                   2           8
# 1          2539329        1             1                   2           8
# 2          2539329        1             1                   2           8
# 3          2539329        1             1                   2           8
# 4          2539329        1             1                   2           8
# ...            ...      ...           ...                 ...         ...
# 32434484   2977660   206209            13                   1          12
# 32434485   2977660   206209            13                   1          12
# 32434486   2977660   206209            13                   1          12
# 32434487   2977660   206209            13                   1          12
# 32434488   2977660   206209            13                   1          12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered
# ...

# %%
# Determine a suitable way to combine the orders_products_combined dataframe
# with your products data set. Make sure you’re using your wrangled, cleaned,
# and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
# product_id could be used to merge the two

# %%
df_ords_prods_merged = df_ords_prods_combined_1.merge(df_prods, on = 'product_id', how = 'left', indicator = True)

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# Confirm the results of the merge using the merge flag

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only        30200
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export the newly created dataframe as orders_products_merged 
# in a suitable format (taking into consideration the size).

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))
